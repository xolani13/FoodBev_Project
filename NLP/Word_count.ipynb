# %%
import os
import pdfplumber
import spacy
import pandas as pd
from spacy.tokens import doc
import enchant
nlp = spacy.load('en_core_web_sm')
directory=os.listdir(r'C:\Users\Ralph\Downloads\Ralph NLP') #specify path where pdfs are stored
is_pdf=[]
for pdfs in directory:
    if pdfs.endswith('.pdf'):
        is_pdf.append(pdfs)

for i in range(0, len(is_pdf)-1, 1):
    pdf = pdfplumber.open(is_pdf[i])
    for page in pdf.pages:
        text = str(page.extract_text())
       
        with open(str(''.join(e for e in is_pdf[i] if (e.isalnum() or e.isspace()))) +".txt", 'a', encoding='utf-8') as fp:
            fp.write(str(text))

is_txt_file=[]
directory=os.listdir(r'C:\Users\Ralph\Downloads\Ralph NLP') #specify path where txt files are stored
for txt_file in directory:
    if txt_file.endswith('.txt'):
        is_txt_file.append(txt_file)

for k in range(0, len(is_txt_file)-1, 1):
    
    myfile = open(str(is_txt_file[k]), 'r' , encoding='utf-8')
    print('File name : '+str(is_txt_file[k]+ "\n"))
    
   

    raw_txt = myfile.read()

    doc = nlp(raw_txt)

    word_count_dict = {}
    word_count_dict['NOUN'] = {}
    word_count_dict['PROPN'] = {}
    word_count_dict['ADJ'] = {}
    word_count_dict['VERB'] = {}

    for token in doc: 
        
        part_of_speech = token.pos_
        if part_of_speech in ['NOUN', 'PROPN', 'ADJ', 'VERB'] and token.is_stop == False:
            word_lemma = token.lemma_

            new_word=''.join(e for e in word_lemma if (e.isalnum() or e.isspace()))
            American_English= enchant.Dict("en_US")
            British_English= enchant.Dict("en_GB")
            
            if len(new_word)<=2:
                pass
            elif new_word.isdigit()==True:
                pass

            elif British_English.check(new_word)==True or American_English.check(new_word)==True:
                current_count = word_count_dict[part_of_speech].get(new_word, 0)

                current_count += 1
                word_count_dict[part_of_speech][new_word] = current_count
                df=pd.DataFrame.from_dict(word_count_dict)
                df.sort_values('NOUN', inplace=True, ascending=False)
                df2=pd.DataFrame.from_dict(word_count_dict)
                df2.sort_values('ADJ', inplace=True, ascending=False)
                df3=pd.DataFrame.from_dict(word_count_dict)
                df3.sort_values('PROPN', inplace=True, ascending=False)
               


            else:
                pass

    print("{}\n ". format( df[['NOUN']].head(15)))
    print("{}\n". format( df2[['ADJ']].head(15)))
    print("{}\n\n\n ". format( df3[['PROPN']].head(15)))
# Out:
# File name : A novel continuous hydrodynamic cavitation technology for the inactivation of pathogens in milkpdf.txt
#
#                NOUN
# milk          363.0
# treatment     255.0
# cavitation    177.0
# effect        150.0
# temperature   129.0
# inactivation   99.0
# rate           93.0
# food           69.0
# flow           66.0
# product        66.0
# protein        66.0
# content        63.0
# aureus         60.0
# condition      60.0
# vitamin        60.0
#
#                ADJ
# thermal       96.0
# high          87.0
# hydrodynamic  84.0
# low           69.0
# raw           57.0
# nutritional   51.0
# similar       45.0
# bacterial     42.0
# rotational    36.0
# fat           33.0
# short         30.0
# present       30.0
# important     27.0
# continuous    27.0
# novel         27.0
#
#               PROPN
# Food           99.0
# cereus         99.0
# Sci            66.0
# Sun            60.0
# Fig            54.0
# Dairy          42.0
# University     39.0
# Chem           30.0
# coli           30.0
# Water          24.0
# Eng            24.0
# hydrodynamic   24.0
# Shandong       21.0
# aureus         21.0
# Korea          21.0
#
#
#
# File name : ApplicationofHighPressureProcessingTechnologyforDairyFoodPreservationFuturePerspectivewithcoverpagev2pdf.txt
#
#                NOUN
# pressure      432.0
# milk          246.0
# food          240.0
# processing    129.0
# treatment     111.0
# effect         93.0
# product        72.0
# cheese         69.0
# protein        57.0
# application    57.0
# property       57.0
# technology     48.0
# preservation   42.0
# temperature    42.0
# time           42.0
#
#                ADJ
# high         273.0
# hydrostatic   42.0
# low           36.0
# nutritional   24.0
# fat           24.0
# thermal       24.0
# resistant     24.0
# microbial     21.0
# unaffected    18.0
# significant   18.0
# non           15.0
# functional    15.0
# great         15.0
# new           15.0
# sensory       15.0
#
#               PROPN
# Food           81.0
# Dairy          66.0
# Sci            48.0
# High           45.0
# Pressure       39.0
# Anim           33.0
# Prod           33.0
# Adv            33.0
# Processing     30.0
# casein         24.0
# Int            21.0
# min            21.0
# Research       18.0
# Preservation   18.0
# Foods          18.0
#
#
#
# File name : Applications of High and Ultra High Pressure Homogenization for Food Safetypdf.txt
#
#                  NOUN
# pressure        258.0
# food            186.0
# inactivation    162.0
# treatment       123.0
# milk            105.0
# temperature      78.0
# homogenization   69.0
# cell             66.0
# activity         57.0
# enzyme           51.0
# product          51.0
# system           51.0
# valve            48.0
# spore            48.0
# application      48.0
#
#                   ADJ
# high            162.0
# homogenization   63.0
# microbial        63.0
# able             51.0
# antimicrobial    51.0
# ultra            30.0
# thermal          30.0
# pathogenic       27.0
# great            24.0
# functional       24.0
# low              24.0
# spore            21.0
# non              18.0
# new              18.0
# fat              18.0
#
#                PROPN
# Int             57.0
# Food            45.0
# Italy           30.0
# Listeria        24.0
# Sci             24.0
# Lopez           21.0
# Authors         21.0
# Lactobacillus   18.0
# Gram            18.0
# Escherichia     15.0
# cereus          15.0
# Burns           15.0
# Homogenizer     15.0
# Lett            15.0
# Tout            15.0
#
#
#
# File name : EFFECT OF HIGH PRESSURE PROCESSING ON MILK COAGULATION PROPERTIEScheckpointpdf.txt
#
#               NOUN
# milk         417.0
# pressure     255.0
# treatment    147.0
# coagulation  126.0
# sample       117.0
# cheese       108.0
# curd         105.0
# processing    87.0
# firmness      84.0
# time          81.0
# effect        75.0
# property      69.0
# yield         63.0
# rennet        63.0
# study         45.0
#
#                    ADJ
# high             228.0
# raw               42.0
# curd              33.0
# significant       24.0
# low               24.0
# present           18.0
# sensory           15.0
# different         15.0
# unheated          15.0
# previous          15.0
# suitable          12.0
# pasteurized       12.0
# thermal           12.0
# hydrostatic       12.0
# microbiological    9.0
#
#                PROPN
# casein          39.0
# Journal         36.0
# Food            36.0
# Dairy           36.0
# Kelly           33.0
# International   30.0
# Science         27.0
# Fox             21.0
# DEVELOPMENT     21.0
# min             21.0
# RURAL           21.0
# RESEARCH        21.0
# PROPERTIES      18.0
# Technologies    18.0
# MILK            18.0
#
#
#
# File name : EnergyConsumptionduringManufacturingofdifferentDairyProductsinaCommercialDairyPlantACaseStudycheckpointpdf.txt
#
#                 NOUN
# consumption    174.0
# energy         168.0
# water          165.0
# steam          147.0
# dairy          138.0
# milk           111.0
# product        105.0
# plant          102.0
# section         66.0
# operation       60.0
# refrigeration   60.0
# method          60.0
# processing      57.0
# table           54.0
# tank            54.0
#
#              ADJ
# cold        33.0
# different   30.0
# electrical  27.0
# commercial  21.0
# effective   18.0
# high        18.0
# proper      15.0
# hot         15.0
# specific    15.0
# optimal     15.0
# raw         15.0
# daily       12.0
# thermal     12.0
# total       12.0
# essential    9.0
#
#               PROPN
# Dairy          30.0
# Engineering    24.0
# Particulars    21.0
# Agricultural   21.0
# Technology     18.0
# Energy         15.0
# Department     15.0
# Food           12.0
# Indian         12.0
# Journal        12.0
# Institute      12.0
# Issue           9.0
# Plant           9.0
# University      9.0
# PROFILE         9.0
#
#
#
# File name : High  pressure  processing  technology  in  dairy  processing A  reviewcheckpointpdf.txt
#
#              NOUN
# pressure    411.0
# milk        264.0
# food        210.0
# treatment   183.0
# cheese      153.0
# effect      105.0
# protein      93.0
# processing   87.0
# product      75.0
# whey         66.0
# property     66.0
# process      54.0
# min          51.0
# technology   51.0
# time         51.0
#
#                ADJ
# high         270.0
# hydrostatic   78.0
# thermal       60.0
# low           48.0
# non           30.0
# free          24.0
# fat           24.0
# similar       21.0
# raw           21.0
# sensory       21.0
# nutritional   21.0
# new           21.0
# ultra         21.0
# pasteurized   18.0
# liquid        18.0
#
#                 PROPN
# Dairy            60.0
# Food             60.0
# Sci              48.0
# casein           42.0
# Anonymous        33.0
# Lopez            27.0
# Swanson          21.0
# Int              21.0
# Harte            21.0
# Trujillo         18.0
# Clark            15.0
# Gould            15.0
# Res              15.0
# RESEARCH         15.0
# Staphylococcus   12.0
#
#
#
# File name : High hydrostatic pressure technology in dairy processinga reviewpdf.txt
